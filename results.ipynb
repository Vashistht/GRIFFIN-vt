# %%
import matplotlib.pyplot as plt

select_only = [2, 4, 6, 8, 12, 16, 20, 24, 32]
rouge_1 = [0.261620, 0.254364, 0.246636, 0.251608, 0.256835, 0.258728, 0.243615, 0.264634, 0.250811]
rouge_2 = [0.075396, 0.079299, 0.068545, 0.076325, 0.073455, 0.072984, 0.062146, 0.089232, 0.070185]
rouge_l = [0.205441, 0.195337, 0.195369, 0.192071, 0.202085, 0.195409, 0.183115, 0.213648, 0.189729]


plt.figure(figsize=(8, 6))

plt.plot(select_only, rouge_1, marker='o', label='ROUGE-1')
plt.plot(select_only, rouge_2, marker='o', label='ROUGE-2')
plt.plot(select_only, rouge_l, marker='o', label='ROUGE-L')

plt.xlabel('select then generate(x-1) tokens')
plt.ylabel('Scores')
plt.title(f'ROUGE Scores for Different select_only Values\n 20 samples, t=.3, max_tokens = 64')
plt.xticks(select_only)
plt.legend()
plt.grid(True)

plt.show()
